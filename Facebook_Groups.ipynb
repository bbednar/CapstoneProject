# %%
pip install wordcloud

# %%
weave
# Out:
# ['Weave']

# %%
import urllib.request
import pandas as pd
import matplotlib.pyplot as plt

#Add scraped data into dataframes
weave_df = pd.read_csv('/content/Weave - Sheet1 (1).csv')
intake_df = pd.read_csv('/content/Intake - Sheet1 (1).csv')
questions_df = pd.read_csv('/content/Questions - Sheet1 (1).csv')
reminders_df = pd.read_csv('/content/Reminders - Sheet1 (1).csv')
schedule_df = pd.read_csv('/content/Schedule - Sheet1 (2).csv')
sr_df = pd.read_csv('/content/Solutionreach - Sheet1 (1).csv')

frames = [weave_df,intake_df,questions_df,reminders_df,schedule_df,sr_df]
all_df = pd.concat(frames)

# %%
stopwords = set(STOPWORDS)
stopadds = ["1y\'","2y\'","1\'","Results ","See", "more\'","question","Dental Office","comment", "1\' ","reply","us","1","2","3","4","5","6","7","8","9", "1y","More"," See More\' ","pt","Matching Comments"," Matching comment ","comments","Matching comment","Man","Managers","patients","Dental","Office","asked","anyone","everyone","please","search","results","Heather","jessica","use","using","Thank","End","Results","Posts","Google","thanks"]
y = 1
for x in stopadds:
  stopwords.add(x)
  y +=1

# %%
#Generate & Display Weave Word Cloud
weave_list = weave_df.values.tolist()
weave_string = ''.join(map(str,weave_list))
weave_wc = WordCloud(background_color="white", max_words = 1000,stopwords=stopwords)
weave_wc.generate(weave_string)
plt.imshow(weave_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#Intake Word Cloud
intake_list = intake_df.values.tolist()
intake_string = ''.join(map(str,intake_list))
intake_wc = WordCloud(background_color="white", max_words = 1000,stopwords=stopwords)
intake_wc.generate(intake_string)
plt.imshow(intake_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#reminders Word Cloud
reminders_list = reminders_df.values.tolist()
reminders_string = ''.join(map(str,reminders_list))
reminders_wc = WordCloud(background_color="white", max_words = 1000,stopwords=stopwords)
reminders_wc.generate(reminders_string)
plt.imshow(reminders_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#sr Word Cloud
sr_list = sr_df.values.tolist()
sr_string = ''.join(map(str,sr_list))
sr_wc = WordCloud(background_color="white", max_words = 1000,stopwords=stopwords)
sr_wc.generate(sr_string)
plt.imshow(sr_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
#schedule Word Cloud
schedule_list = schedule_df.values.tolist()
schedule_string = ''.join(map(str,schedule_list))
schedule_wc = WordCloud(background_color="white", max_words = 1000,stopwords=stopwords)
schedule_wc.generate(schedule_string)
plt.imshow(schedule_wc, interpolation='bilinear')
plt.axis('off')
plt.show()
